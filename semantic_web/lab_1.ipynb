# %%
# Send SPARQL query to SPARQL endpoint, store and output result.

from urllib import request as urllib

endpointURL = "http://dbpedia.org/sparql"
query = """
SELECT distinct ?elvis ?elvisbday WHERE {
  <http://dbpedia.org/resource/Elvis_Presley>
  <http://www.w3.org/2002/07/owl#sameAs> ?elvis .  #find all resources that refer to the same individual as <http://dbpedia.org/resource/Elvis_Presley>
  <http://dbpedia.org/resource/Elvis_Presley>
  <http://dbpedia.org/ontology/birthDate> ?elvisbday .
}
"""
escapedQuery = urllib.quote(query)

# %%
requestURL = endpointURL + "?query=" + escapedQuery
request = urllib.Request(requestURL)

result = urllib.urlopen(request)
print(result.read().decode('utf-8'))
# Out:
# <sparql xmlns="http://www.w3.org/2005/sparql-results#" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.w3.org/2001/sw/DataAccess/rf1/result2.xsd">
#  <head>
#   <variable name="elvis"/>
#   <variable name="elvisbday"/>
#  </head>
#  <results distinct="false" ordered="true">
#   <result>
#    <binding name="elvis"><uri>http://rdf.freebase.com/ns/m.02jq1</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://api.nytimes.com/svc/semantic/v2/concept/name/nytd_per/Presley,%20Elvis</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://viaf.org/viaf/23404836</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://yago-knowledge.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://d-nb.info/gnd/118596357</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sw.cyc.com/concept/Mx4r2ugxihMoRKq3kp88jDTW-Q</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sw.cyc.com/concept/Mx4rvdRAMpwpEbGdrcN5Y29ycA</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://data.europa.eu/euodp/jrc-names/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://commons.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://musicbrainz.org/artist/01809552-4f87-45b0-afff-2c6f0730a3be</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://www.wikidata.org/entity/Q303</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://data.bibliotheken.nl/id/thes/p069002363</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://af.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://als.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://am.dbpedia.org/resource/ኤልቭስ_ፕሬስሊ</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://an.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ar.dbpedia.org/resource/إلفيس_بريسلي</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://arz.dbpedia.org/resource/ايلڤيس_پريسلى</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ast.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://az.dbpedia.org/resource/Elvis_Presli</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://azb.dbpedia.org/resource/الویس_پریسلی</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ba.dbpedia.org/resource/Элвис_Пресли</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://bar.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://be.dbpedia.org/resource/Элвіс_Прэслі</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://bg.dbpedia.org/resource/Елвис_Пресли</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://bn.dbpedia.org/resource/এলভিস_প্রেসলি</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://br.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://bs.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ca.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ckb.dbpedia.org/resource/ئێلڤیس_پریسلی</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://cs.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://cy.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://da.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://de.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://el.dbpedia.org/resource/Έλβις_Πρίσλεϊ</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://eo.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://es.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://et.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://eu.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://fa.dbpedia.org/resource/الویس_پرسلی</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://fi.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://fo.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://fr.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://fy.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ga.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://gd.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://gl.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://he.dbpedia.org/resource/אלביס_פרסלי</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://hi.dbpedia.org/resource/एल्विस_प्रेस्ली</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://hr.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ht.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://hu.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://hy.dbpedia.org/resource/Էլվիս_Փրեսլի</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ia.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://id.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://io.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://is.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://it.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ja.dbpedia.org/resource/エルヴィス・プレスリー</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://jv.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ka.dbpedia.org/resource/ელვის_პრესლი</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://kk.dbpedia.org/resource/Элвис_Пресли</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://kn.dbpedia.org/resource/ಎಲ್ವಿಸ್_ಪ್ರೀಸ್ಲಿ</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ko.dbpedia.org/resource/엘비스_프레슬리</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ky.dbpedia.org/resource/Элвис_Пресли</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://la.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://lb.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://li.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://lmo.dbpedia.org/resource/Elvis_Aaron_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://lt.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://lv.dbpedia.org/resource/Elviss_Preslijs</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://mg.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://min.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://mk.dbpedia.org/resource/Елвис_Пресли</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ml.dbpedia.org/resource/എൽവിസ്_പ്രെസ്‌ലി</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://mn.dbpedia.org/resource/Элвис_Пресли</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://mr.dbpedia.org/resource/एल्व्हिस_प्रेस्ली</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://mrj.dbpedia.org/resource/Пресли,_Элвис</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ms.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://my.dbpedia.org/resource/ပရက်စလေ</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://mzn.dbpedia.org/resource/الویس_پریسلی</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://nah.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://new.dbpedia.org/resource/एल्भिस_प्रेस्ली</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://nl.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://nn.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://no.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://oc.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://pa.dbpedia.org/resource/ਐਲਵਿਸ_ਪਰੈਸਲੇ</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://pl.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://pms.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://pnb.dbpedia.org/resource/ایلوس_پریسلے</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://pt.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://qu.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ro.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ru.dbpedia.org/resource/Пресли,_Элвис</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sah.dbpedia.org/resource/Элвис_Пресли</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://scn.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sco.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sh.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://si.dbpedia.org/resource/එල්විස්_ප්‍රෙස්ලි</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://simple.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sk.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sl.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sq.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sr.dbpedia.org/resource/Елвис_Пресли</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://su.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sv.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://sw.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ta.dbpedia.org/resource/எல்விஸ்_பிரெஸ்லி</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://tg.dbpedia.org/resource/Элвис_Пресли</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://th.dbpedia.org/resource/เอลวิส_เพรสลีย์</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://tl.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://tr.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://tt.dbpedia.org/resource/Elvis_Presli</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://uk.dbpedia.org/resource/Елвіс_Преслі</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ur.dbpedia.org/resource/ایلوس_پریسلے</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://uz.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://vec.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://vi.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://vo.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://war.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://yi.dbpedia.org/resource/עלוויס_פרעסלי</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://yo.dbpedia.org/resource/Elvis_Presley</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://zh.dbpedia.org/resource/埃爾維斯·皮禮士利</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>http://ce.dbpedia.org/resource/Пресли,_Элвис</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#   <result>
#    <binding name="elvis"><uri>https://global.dbpedia.org/id/2oh6K</uri></binding>
#    <binding name="elvisbday"><literal datatype="http://www.w3.org/2001/XMLSchema#date">1935-01-08</literal></binding>
#   </result>
#  </results>
# </sparql>
